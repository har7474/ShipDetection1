# %% [markdown]
# # Importing libraries
#
# The necessary libraries required for implementing the Faster R-CNN model are imported in the code block below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, random, cv2, pickle, json, itertools
import imgaug.augmenters as iaa
import imgaug.imgaug

from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.utils import class_weight
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Add, Input, Conv2D, Dropout, Activation, BatchNormalization, MaxPooling2D, ZeroPadding2D, AveragePooling2D, Flatten, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *

# %%
def show_final_history(history):
    
    plt.style.use("ggplot")
    fig, ax = plt.subplots(1,2,figsize=(15,5))
    ax[0].set_title('Loss')
    ax[1].set_title('Accuracy')
    ax[0].plot(history.history['loss'],label='Train Loss')
    ax[0].plot(history.history['val_loss'],label='Validation Loss')
    ax[1].plot(history.history['accuracy'],label='Train Accuracy')
    ax[1].plot(history.history['val_accuracy'],label='Validation Accuracy')
    
    ax[0].legend(loc='upper right')
    ax[1].legend(loc='lower right')
    plt.show();
    pass

# %%
def plot_confusion_matrix(cm,classes,title='Confusion Matrix',cmap=plt.cm.Blues):
    
#     np.seterr(divide='ignore',invalid='ignore')
    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes,rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f'
    thresh = cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j],fmt),
                horizontalalignment="center",
                color="white" if cm[i,j] > thresh else "black")
        pass
    
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    pass

# %% [markdown]
# # Uploading the images

# %%
datasets = ['C:\\Users\harsh\OneDrive\\Desktop\\detecting ship\\sourcecode\\satellite-imagery-of-ships']

class_names = ["no-ship","ship"]

class_name_labels = {class_name:i for i,class_name in enumerate(class_names)}

num_classes = len(class_names)
class_name_labels
# Out:
# {'no-ship': 0, 'ship': 1}

# %%
def load_data():
    images, labels = [], []
    
    for dataset in datasets:
        
        for folder in os.listdir(dataset):
            label = class_name_labels[folder]
            
            for file in tqdm(os.listdir(os.path.join(dataset,folder))):
                
                img_path = os.path.join(dataset,folder,file)
                
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (48,48))
                
                images.append(img)
                labels.append(label)
                pass
            pass
        
        images = np.array(images,dtype=np.float32)/255.0
        labels = np.array(labels,dtype=np.float32)
        pass
    
    return (images, labels)
    pass

# %%
(images, labels) = load_data()
images.shape, labels.shape
# Out:
# 100%|██████████| 3000/3000 [00:10<00:00, 296.96it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 301.39it/s]
# ((4000, 48, 48, 3), (4000,))

# %%
n_labels = labels.shape[0]

_, count = np.unique(labels, return_counts=True)

df = pd.DataFrame(data = count)
df['Class Label'] = class_names
df.columns = ['Count','Class-Label']
df.set_index('Class-Label',inplace=True)
df
# Out:
#              Count
# Class-Label
# no-ship       3000
# ship          1000

# %%
df.plot.bar(rot=0)
plt.title("distribution of images per class");

# %% [markdown]
# As it can be seen that the data is skewed towards the *no-ship* class with 75% of images belonging to that very specific class.

# %%
plt.pie(count,
       explode=(0,0),
       labels=class_names,
       autopct="%1.2f%%")
plt.axis('equal');

# %% [markdown]
# # Augmenting Images of Minority Class

# %%
def augment_add(images, seq, labels):
    
    augmented_images, augmented_labels = [],[]
    for idx,img in tqdm(enumerate(images)):
        
        if labels[idx] == 1:
            image_aug_1 = seq.augment_image(image=img)
            image_aug_2 = seq.augment_image(image=img)
            augmented_images.append(image_aug_1)
            augmented_images.append(image_aug_2)
            augmented_labels.append(labels[idx])
            augmented_labels.append(labels[idx])
        pass
    
    augmented_images = np.array(augmented_images, dtype=np.float32)
    augmented_labels = np.array(augmented_labels, dtype=np.float32)
    
    return (augmented_images, augmented_labels)
    pass

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0,0.1)),
    iaa.LinearContrast((0.75,1.5)),
    iaa.Multiply((0.8,1.2), per_channel=0.2),
    iaa.Affine(
        scale={'x':(0.8,1.2), "y":(0.8,1.2)},
        translate_percent={"x":(-0.2,0.2),"y":(-0.2,0.2)},
        rotate=(-25,25),
        shear=(-8,8)
    )
], random_order=True)

# %%
if seq:
    (aug_images, aug_labels) = augment_add(images, seq, labels)
    images = np.concatenate([images, aug_images])
    labels = np.concatenate([labels, aug_labels])
# Out:
# 4000it [00:03, 1022.59it/s]

# %%
images.shape, labels.shape
# Out:
# ((6000, 48, 48, 3), (6000,))

# %%
if seq:
    _, count = np.unique(labels, return_counts=True)

    plt.pie(count,
           explode=(0,0),
           labels=class_names,
           autopct="%1.2f%%")
    plt.axis('equal');

# %% [markdown]
# # One Hot Encoding Variables

# %%
labels = to_categorical(labels)

# %% [markdown]
# # Training, Validation and Testing

# %%
np.random.seed(42)
np.random.shuffle(images)

np.random.seed(42)
np.random.shuffle(labels)

# %% [markdown]
# ## Spliting of data
#
# * 70% - Training
# * 20% - Validation
# * 10% - Testing

# %%
total_count = len(images)
total_count

train = int(0.7*total_count)
val = int(0.2*total_count)
test = int(0.1*total_count)

train_images, train_labels = images[:train], labels[:train]
val_images, val_labels = images[train:(val+train)], labels[train:(val+train)]
test_images, test_labels = images[-test:], labels[-test:]

train_images.shape, val_images.shape, test_images.shape
# Out:
# ((4200, 48, 48, 3), (1200, 48, 48, 3), (600, 48, 48, 3))

# %%
if not seq:
    count_labels = train_labels.sum(axis=0)

    classTotals = train_labels.sum(axis=0)
    classWeight = {}

    for i in range(0,len(classTotals)):
        classWeight[i] = classTotals.max()/classTotals[i]
        pass
    print(classWeight)

# %%
def conv_block(X,k,filters,stage,block,s=2):
    
    conv_base_name = 'conv_' + str(stage)+block+'_branch'
    bn_base_name = 'bn_'+str(stage)+block+"_branch"
    
    F1 = filters
    
    X = Conv2D(filters=F1, kernel_size=(k,k), strides=(s,s),
              padding='same',name=conv_base_name+'2a')(X)
    X = BatchNormalization(name=bn_base_name+'2a')(X)
    X = Activation('relu')(X)
    
    return X
    pass

# %%
def basic_model(input_shape,classes):
    
    X_input = Input(input_shape)
    
    X = ZeroPadding2D((5,5))(X_input)
    
    X = Conv2D(16,(3,3),strides=(2,2),name='conv1',padding="same")(X)
    X = BatchNormalization(name='bn_conv1')(X)
    
    # stage 2
    X = conv_block(X,3,32,2,block='A',s=1)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)

#     Stage 3
    X = conv_block(X,5,32,3,block='A',s=2)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)
    
#     Stage 4
    X = conv_block(X,3,64,4,block='A',s=1)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)
    
#   Output Layer
    X = Flatten()(X)
    X = Dense(64)(X)
    X = Dropout(0.5)(X)
    
    X = Dense(128)(X)
    X = Activation("relu")(X)
    
    X = Dense(classes,activation="softmax",name="fc"+str(classes))(X)
    
    model = Model(inputs=X_input,outputs=X,name='Feature_Extraction_and_FC')
    
    return model
    pass

# %%
model = basic_model(input_shape=(48,48,3),classes=2)

# %%
#plot_model(model,to_file='basic_model.png')
#SVG(model_to_dot(model).create(prog='dot',format='svg'))

model.summary()
# Out:
# Model: "Feature_Extraction_and_FC"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  zero_padding2d_3 (ZeroPaddi  (None, 58, 58, 3)        0
#  ng2D)
#
#  conv1 (Conv2D)              (None, 29, 29, 16)        448
#
#  bn_conv1 (BatchNormalizatio  (None, 29, 29, 16)       64
#  n)
#
#  conv_2A_branch2a (Conv2D)   (None, 29, 29, 32)        4640
#
#  bn_2A_branch2a (BatchNormal  (None, 29, 29, 32)       128
#  ization)
#
#  activation_12 (Activation)  (None, 29, 29, 32)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 14, 14, 32)        0
#
#  conv_3A_branch2a (Conv2D)   (None, 7, 7, 32)          25632
#
#  bn_3A_branch2a (BatchNormal  (None, 7, 7, 32)         128
#  ization)
#
#  activation_13 (Activation)  (None, 7, 7, 32)          0
#
#  max_pooling2d_10 (MaxPoolin  (None, 3, 3, 32)         0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 3, 3, 32)          0
#
#  conv_4A_branch2a (Conv2D)   (None, 3, 3, 64)          18496
#
#  bn_4A_branch2a (BatchNormal  (None, 3, 3, 64)         256
#  ization)
#
#  activation_14 (Activation)  (None, 3, 3, 64)          0
#
#  max_pooling2d_11 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 1, 1, 64)          0
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  activation_15 (Activation)  (None, 128)               0
#
#  fc2 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 62,530
# Trainable params: 62,242
# Non-trainable params: 288
# _________________________________________________________________

# %% [markdown]
# ## Compiling the Model

# %%
opt = Adam(lr=1e-3)
model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# c:\Users\harsh\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
checkpoint = ModelCheckpoint("model_weights.h5",monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')
logs = TensorBoard("logs")

# %% [markdown]
# # Training model

# %%
epochs = 50
batch_size = 16

history = model.fit(train_images,train_labels,
                   steps_per_epoch=len(train_images)//batch_size,
                   epochs=epochs,
                   verbose=1, 
                   validation_data=(val_images,val_labels),
                   validation_steps=len(val_images)//batch_size,
                   callbacks=[checkpoint, logs]
#                    class_weight=classWeight # Uncomment if AUGMENTATION is set to FALSE
                   )
# Out:
# Epoch 1/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.4327 - accuracy: 0.7998
# Epoch 1: val_accuracy improved from -inf to 0.88750, saving model to model_weights.h5
# 262/262 [==============================] - 13s 44ms/step - loss: 0.4318 - accuracy: 0.8001 - val_loss: 0.3338 - val_accuracy: 0.8875
# Epoch 2/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.1728 - accuracy: 0.9364
# Epoch 2: val_accuracy improved from 0.88750 to 0.95500, saving model to model_weights.h5
# 262/262 [==============================] - 11s 41ms/step - loss: 0.1730 - accuracy: 0.9365 - val_loss: 0.1074 - val_accuracy: 0.9550
# Epoch 3/50
# 262/262 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9493
# Epoch 3: val_accuracy improved from 0.95500 to 0.97250, saving model to model_weights.h5
# 262/262 [==============================] - 8s 31ms/step - loss: 0.1340 - accuracy: 0.9493 - val_loss: 0.0781 - val_accuracy: 0.9725
# Epoch 4/50
# 262/262 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9549
# Epoch 4: val_accuracy did not improve from 0.97250
# 262/262 [==============================] - 7s 28ms/step - loss: 0.1245 - accuracy: 0.9549 - val_loss: 0.1432 - val_accuracy: 0.9367
# Epoch 5/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9628
# Epoch 5: val_accuracy improved from 0.97250 to 0.98167, saving model to model_weights.h5
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0985 - accuracy: 0.9628 - val_loss: 0.0540 - val_accuracy: 0.9817
# Epoch 6/50
# 260/262 [============================>.] - ETA: 0s - loss: 0.0780 - accuracy: 0.9718
# Epoch 6: val_accuracy improved from 0.98167 to 0.98333, saving model to model_weights.h5
# 262/262 [==============================] - 9s 35ms/step - loss: 0.0782 - accuracy: 0.9718 - val_loss: 0.0571 - val_accuracy: 0.9833
# Epoch 7/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9754
# Epoch 7: val_accuracy improved from 0.98333 to 0.98417, saving model to model_weights.h5
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0768 - accuracy: 0.9754 - val_loss: 0.0535 - val_accuracy: 0.9842
# Epoch 8/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9769
# Epoch 8: val_accuracy did not improve from 0.98417
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0715 - accuracy: 0.9770 - val_loss: 0.0669 - val_accuracy: 0.9725
# Epoch 9/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9829
# Epoch 9: val_accuracy did not improve from 0.98417
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0493 - accuracy: 0.9829 - val_loss: 0.0732 - val_accuracy: 0.9842
# Epoch 10/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9776
# Epoch 10: val_accuracy improved from 0.98417 to 0.98667, saving model to model_weights.h5
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0600 - accuracy: 0.9777 - val_loss: 0.0462 - val_accuracy: 0.9867
# Epoch 11/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9802
# Epoch 11: val_accuracy did not improve from 0.98667
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0555 - accuracy: 0.9802 - val_loss: 0.0458 - val_accuracy: 0.9817
# Epoch 12/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9845
# Epoch 12: val_accuracy improved from 0.98667 to 0.98917, saving model to model_weights.h5
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0430 - accuracy: 0.9845 - val_loss: 0.0459 - val_accuracy: 0.9892
# Epoch 13/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9840
# Epoch 13: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0521 - accuracy: 0.9840 - val_loss: 0.0935 - val_accuracy: 0.9683
# Epoch 14/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9831
# Epoch 14: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 9s 35ms/step - loss: 0.0474 - accuracy: 0.9831 - val_loss: 0.0532 - val_accuracy: 0.9842
# Epoch 15/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9873
# Epoch 15: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0380 - accuracy: 0.9872 - val_loss: 0.0420 - val_accuracy: 0.9892
# Epoch 16/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9881
# Epoch 16: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 12s 46ms/step - loss: 0.0363 - accuracy: 0.9881 - val_loss: 0.0705 - val_accuracy: 0.9767
# Epoch 17/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9916
# Epoch 17: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0303 - accuracy: 0.9917 - val_loss: 0.0387 - val_accuracy: 0.9892
# Epoch 18/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9868
# Epoch 18: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0367 - accuracy: 0.9869 - val_loss: 0.0858 - val_accuracy: 0.9675
# Epoch 19/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9880
# Epoch 19: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0315 - accuracy: 0.9878 - val_loss: 0.0388 - val_accuracy: 0.9858
# Epoch 20/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9894
# Epoch 20: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0287 - accuracy: 0.9894 - val_loss: 0.0524 - val_accuracy: 0.9883
# Epoch 21/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9876
# Epoch 21: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0311 - accuracy: 0.9876 - val_loss: 0.0419 - val_accuracy: 0.9892
# Epoch 22/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9919
# Epoch 22: val_accuracy did not improve from 0.98917
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.0337 - val_accuracy: 0.9892
# Epoch 23/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9928
# Epoch 23: val_accuracy improved from 0.98917 to 0.99000, saving model to model_weights.h5
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0395 - val_accuracy: 0.9900
# Epoch 24/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9928
# Epoch 24: val_accuracy improved from 0.99000 to 0.99083, saving model to model_weights.h5
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0246 - accuracy: 0.9928 - val_loss: 0.0366 - val_accuracy: 0.9908
# Epoch 25/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9910
# Epoch 25: val_accuracy did not improve from 0.99083
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0310 - accuracy: 0.9910 - val_loss: 0.0537 - val_accuracy: 0.9842
# Epoch 26/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9921
# Epoch 26: val_accuracy did not improve from 0.99083
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0238 - accuracy: 0.9921 - val_loss: 0.0394 - val_accuracy: 0.9900
# Epoch 27/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9930
# Epoch 27: val_accuracy did not improve from 0.99083
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0233 - accuracy: 0.9930 - val_loss: 0.0394 - val_accuracy: 0.9875
# Epoch 28/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9939
# Epoch 28: val_accuracy did not improve from 0.99083
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0240 - accuracy: 0.9939 - val_loss: 0.0437 - val_accuracy: 0.9892
# Epoch 29/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9921
# Epoch 29: val_accuracy did not improve from 0.99083
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.0494 - val_accuracy: 0.9892
# Epoch 30/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9926
# Epoch 30: val_accuracy did not improve from 0.99083
# 262/262 [==============================] - 11s 42ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.1295 - val_accuracy: 0.9675
# Epoch 31/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9912
# Epoch 31: val_accuracy improved from 0.99083 to 0.99167, saving model to model_weights.h5
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.0361 - val_accuracy: 0.9917
# Epoch 32/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9928
# Epoch 32: val_accuracy improved from 0.99167 to 0.99250, saving model to model_weights.h5
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0190 - accuracy: 0.9928 - val_loss: 0.0325 - val_accuracy: 0.9925
# Epoch 33/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9919
# Epoch 33: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0236 - accuracy: 0.9919 - val_loss: 0.0324 - val_accuracy: 0.9917
# Epoch 34/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9937
# Epoch 34: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.0431 - val_accuracy: 0.9892
# Epoch 35/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9964
# Epoch 35: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.0942 - val_accuracy: 0.9783
# Epoch 36/50
# 260/262 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9941
# Epoch 36: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.0395 - val_accuracy: 0.9908
# Epoch 37/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9917
# Epoch 37: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0269 - accuracy: 0.9917 - val_loss: 0.0424 - val_accuracy: 0.9883
# Epoch 38/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9962
# Epoch 38: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0158 - accuracy: 0.9962 - val_loss: 0.0338 - val_accuracy: 0.9900
# Epoch 39/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9946
# Epoch 39: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0440 - val_accuracy: 0.9900
# Epoch 40/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9919
# Epoch 40: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0213 - accuracy: 0.9919 - val_loss: 0.0433 - val_accuracy: 0.9875
# Epoch 41/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9955
# Epoch 41: val_accuracy did not improve from 0.99250
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.0439 - val_accuracy: 0.9892
# Epoch 42/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9962
# Epoch 42: val_accuracy improved from 0.99250 to 0.99333, saving model to model_weights.h5
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0365 - val_accuracy: 0.9933
# Epoch 43/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9921
# Epoch 43: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0296 - accuracy: 0.9921 - val_loss: 0.0368 - val_accuracy: 0.9917
# Epoch 44/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9952
# Epoch 44: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.0379 - val_accuracy: 0.9917
# Epoch 45/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9953
# Epoch 45: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0117 - accuracy: 0.9953 - val_loss: 0.0413 - val_accuracy: 0.9917
# Epoch 46/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9946
# Epoch 46: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.1402 - val_accuracy: 0.9667
# Epoch 47/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9923
# Epoch 47: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0204 - accuracy: 0.9923 - val_loss: 0.0296 - val_accuracy: 0.9917
# Epoch 48/50
#  86/262 [========>.....................] - ETA: 4s - loss: 0.0156 - accuracy: 0.9952WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 13100 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 48: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 3s 12ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.0352 - val_accuracy: 0.9900

# %% [markdown]
# # Plotting Loss and Accuracy
#
# The loss and accuracy for the training and validation datasets is plotted using the *show_final_history* function

# %%
show_final_history(history)

# %% [markdown]
# # Confusion Matrix for Validation dataset
#
# The confusion matrix

# %%
val_pred = model.predict(val_images)
val_pred = np.argmax(val_pred,axis=1)
val_pred.shape
# Out:
# 38/38 [==============================] - 1s 13ms/step
# (1200,)

# %%
val_actual = np.argmax(val_labels,axis=1)

cnf_mat = confusion_matrix(val_actual, val_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat,classes=class_names)
plt.grid(None)
plt.show();

# %% [markdown]
# ### With Augmentation:
#
# * Precision:
#     - *no-ship* : 0.942
#     - *ship* : 0.989
#
#
# * Recall:
#     - *no-ship* : 0.99
#     - *ship* : 0.94
#
# ### With class weights
#
# * Precision:
#     - *no-ship* : 1.00
#     - *ship* : 0.99
#
#
# * Recall:
#     - *no-ship* : 0.99
#     - *ship* : 1.00

# %% [markdown]
# # Confusion Matrix for Testing Dataset

# %%
test_pred = model.predict(test_images)
test_pred = np.argmax(test_pred,axis=1)
test_pred.shape
# Out:
# 19/19 [==============================] - 0s 15ms/step
# (600,)

# %%
test_actual = np.argmax(test_labels,axis=1)

cnf_mat_test = confusion_matrix(test_actual, test_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat_test,classes=class_names)
plt.grid(None)
plt.show()

# %% [markdown]
# # Checking the model

# %%
rnd_idx = random.sample(range(0,400),10)

class_labels = {i:class_name for (class_name,i) in class_name_labels.items()}
class_labels

# fig, ax = plt.subplots(2,5,figsize=(5,5))

for i,idx in enumerate(rnd_idx):
    
    plt.imshow(test_images[idx])
    plt.title("Actual: {}\nPredicted: {}".format(class_labels[test_actual[idx]],class_labels[test_pred[idx]]))
    plt.grid(None)
    plt.show()
    pass
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Saving the model**

# %%
model.save("ship-model.h5")
